# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size =2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 717

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | svetlaya
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | san juan bautista
# Processing Record 8 of Set 1 | hithadhoo
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | iskateley
# Processing Record 11 of Set 1 | havoysund
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | yankton
# Processing Record 16 of Set 1 | yumen
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | sao jose da laje
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | taoudenni
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | pucallpa
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | poltava
# Processing Record 35 of Set 1 | norfolk
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | kainantu
# Processing Record 38 of Set 1 | shelton
# Processing Record 39 of Set 1 | los llanos de aridane
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | tieli
# Processing Record 43 of Set 1 | fukue
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | san patricio
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | poum
# Processing Record 48 of Set 1 | abong mbang
# Processing Record 49 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 1 | yulara
# Processing Record 1 of Set 2 | asau
# Processing Record 2 of Set 2 | kodinar
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | presidencia roque saenz pena
# Processing Record 6 of Set 2 | panama city
# Processing Record 7 of Set 2 | handwara
# City not found. Skipping...
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | qaqortoq
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | grong
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | ponta delgada
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | atbasar
# Processing Record 23 of Set 2 | janow lubelski
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | sao joao da barra
# Processing Record 26 of Set 2 | krasnyy chikoy
# Processing Record 27 of Set 2 | linxia
# Processing Record 28 of Set 2 | kiunga
# Processing Record 29 of Set 2 | port moresby
# Processing Record 30 of Set 2 | ryotsu
# Processing Record 31 of Set 2 | leningradskiy
# Processing Record 32 of Set 2 | acapulco
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | mataura
# Processing Record 35 of Set 2 | tosya
# Processing Record 36 of Set 2 | moron
# Processing Record 37 of Set 2 | sarangani
# Processing Record 38 of Set 2 | vestmannaeyjar
# Processing Record 39 of Set 2 | boden
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | waipawa
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 2 | tautira
# Processing Record 48 of Set 2 | tongliao
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | mancio lima
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | magadi
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | huron
# Processing Record 9 of Set 3 | vallenar
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | vico equense
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | port-gentil
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | greenville
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | benghazi
# Processing Record 23 of Set 3 | fort nelson
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | kidal
# Processing Record 26 of Set 3 | sandusky
# Processing Record 27 of Set 3 | nibbar
# Processing Record 28 of Set 3 | prince rupert
# Processing Record 29 of Set 3 | zaoyang
# Processing Record 30 of Set 3 | torres
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | sorland
# Processing Record 34 of Set 3 | petauke
# Processing Record 35 of Set 3 | yambio
# Processing Record 36 of Set 3 | grand gaube
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | san quintin
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 3 | vardo
# Processing Record 42 of Set 3 | wanning
# Processing Record 43 of Set 3 | diamantina
# Processing Record 44 of Set 3 | murdochville
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | vilhena
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | hambantota
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | shakiso
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | dukat
# Processing Record 4 of Set 4 | bairiki
# Processing Record 5 of Set 4 | wundanyi
# Processing Record 6 of Set 4 | panaba
# Processing Record 7 of Set 4 | lensk
# Processing Record 8 of Set 4 | mulanje
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | san ramon
# Processing Record 12 of Set 4 | sault sainte marie
# Processing Record 13 of Set 4 | tommot
# Processing Record 14 of Set 4 | sibu
# Processing Record 15 of Set 4 | palakollu
# Processing Record 16 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | atascocita
# Processing Record 18 of Set 4 | envira
# Processing Record 19 of Set 4 | salta
# Processing Record 20 of Set 4 | odesskoye
# Processing Record 21 of Set 4 | taloqan
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | nishihara
# Processing Record 25 of Set 4 | basco
# Processing Record 26 of Set 4 | zapolyarnyy
# Processing Record 27 of Set 4 | baruun-urt
# Processing Record 28 of Set 4 | ponta do sol
# Processing Record 29 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | kirkuk
# Processing Record 32 of Set 4 | sola
# Processing Record 33 of Set 4 | salgueiro
# Processing Record 34 of Set 4 | college
# Processing Record 35 of Set 4 | plettenberg bay
# Processing Record 36 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 4 | komsomolskiy
# Processing Record 38 of Set 4 | aksu
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | yaan
# Processing Record 41 of Set 4 | sinegorye
# Processing Record 42 of Set 4 | aguimes
# Processing Record 43 of Set 4 | neryungri
# Processing Record 44 of Set 4 | dunbar
# Processing Record 45 of Set 4 | saskylakh
# Processing Record 46 of Set 4 | takapau
# Processing Record 47 of Set 4 | naze
# Processing Record 48 of Set 4 | milkovo
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | the valley
# Processing Record 1 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | seymchan
# Processing Record 4 of Set 5 | oyama
# Processing Record 5 of Set 5 | bontang
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | saint-georges
# Processing Record 8 of Set 5 | soyo
# Processing Record 9 of Set 5 | jasper
# Processing Record 10 of Set 5 | moramanga
# Processing Record 11 of Set 5 | jalu
# Processing Record 12 of Set 5 | chipata
# Processing Record 13 of Set 5 | scarborough
# Processing Record 14 of Set 5 | teluknaga
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | washim
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | honningsvag
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | mildura
# Processing Record 21 of Set 5 | beyneu
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | vanersborg
# Processing Record 24 of Set 5 | berdigestyakh
# Processing Record 25 of Set 5 | laguna
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 5 | sistranda
# Processing Record 31 of Set 5 | puerto ayacucho
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | airai
# Processing Record 34 of Set 5 | christchurch
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | japura
# Processing Record 37 of Set 5 | longyearbyen
# Processing Record 38 of Set 5 | kasongo-lunda
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | ferme-neuve
# Processing Record 41 of Set 5 | bonavista
# Processing Record 42 of Set 5 | qaanaaq
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | fare
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | moussoro
# Processing Record 47 of Set 5 | beringovskiy
# Processing Record 48 of Set 5 | roald
# Processing Record 49 of Set 5 | ngunguru
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | salinas
# Processing Record 2 of Set 6 | yaring
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | atikokan
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | tobe
# Processing Record 7 of Set 6 | saint-francois
# Processing Record 8 of Set 6 | cordoba
# Processing Record 9 of Set 6 | nipawin
# Processing Record 10 of Set 6 | lima
# Processing Record 11 of Set 6 | byron bay
# Processing Record 12 of Set 6 | lugovoy
# Processing Record 13 of Set 6 | la ronge
# Processing Record 14 of Set 6 | hobyo
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 18 of Set 6 | port augusta
# Processing Record 19 of Set 6 | thinadhoo
# Processing Record 20 of Set 6 | washington
# Processing Record 21 of Set 6 | san cristobal
# Processing Record 22 of Set 6 | lazaro cardenas
# Processing Record 23 of Set 6 | shaowu
# Processing Record 24 of Set 6 | tatarka
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | bafoulabe
# Processing Record 27 of Set 6 | neustadt
# Processing Record 28 of Set 6 | bushehr
# Processing Record 29 of Set 6 | akdagmadeni
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | olga
# Processing Record 32 of Set 6 | amapa
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | khromtau
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 6 | maniitsoq
# Processing Record 38 of Set 6 | mouzouras
# Processing Record 39 of Set 6 | callaway
# Processing Record 40 of Set 6 | bhadrachalam
# Processing Record 41 of Set 6 | cap malheureux
# Processing Record 42 of Set 6 | luanda
# Processing Record 43 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 6 | bilma
# Processing Record 45 of Set 6 | kaitangata
# Processing Record 46 of Set 6 | baikunthpur
# Processing Record 47 of Set 6 | san policarpo
# Processing Record 48 of Set 6 | gobabis
# Processing Record 49 of Set 6 | maragogi
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | key west
# Processing Record 2 of Set 7 | avera
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | bowen
# Processing Record 6 of Set 7 | rota
# Processing Record 7 of Set 7 | leo
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | mexico
# Processing Record 10 of Set 7 | claresholm
# Processing Record 11 of Set 7 | saint-leu
# Processing Record 12 of Set 7 | ramsar
# Processing Record 13 of Set 7 | afgoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | lebu
# Processing Record 15 of Set 7 | camacha
# Processing Record 16 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 7 | herat
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | ust-ilimsk
# Processing Record 20 of Set 7 | coihaique
# Processing Record 21 of Set 7 | domoni
# Processing Record 22 of Set 7 | igrim
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | gizo
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | marshall
# Processing Record 27 of Set 7 | tupik
# Processing Record 28 of Set 7 | gigmoto
# Processing Record 29 of Set 7 | eureka
# Processing Record 30 of Set 7 | santa maria
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 33 of Set 7 | bitam
# Processing Record 34 of Set 7 | rexburg
# Processing Record 35 of Set 7 | swift current
# Processing Record 36 of Set 7 | san vicente
# Processing Record 37 of Set 7 | pitimbu
# Processing Record 38 of Set 7 | nakhon thai
# Processing Record 39 of Set 7 | bela
# Processing Record 40 of Set 7 | baculin
# Processing Record 41 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 7 | evensk
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | mizdah
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | daru
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | zhigansk
# Processing Record 49 of Set 7 | las matas de farfan
# Processing Record 50 of Set 7 | skibbereen
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | dingle
# Processing Record 4 of Set 8 | pemangkat
# Processing Record 5 of Set 8 | iglesias
# Processing Record 6 of Set 8 | pedro juan caballero
# Processing Record 7 of Set 8 | vaitape
# Processing Record 8 of Set 8 | coronado
# Processing Record 9 of Set 8 | belaya gora
# Processing Record 10 of Set 8 | cambyreta
# City not found. Skipping...
# Processing Record 11 of Set 8 | konstantinovka
# Processing Record 12 of Set 8 | wewak
# Processing Record 13 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 14 of Set 8 | boca do acre
# Processing Record 15 of Set 8 | banda aceh
# Processing Record 16 of Set 8 | xapuri
# Processing Record 17 of Set 8 | moerai
# Processing Record 18 of Set 8 | kahului
# Processing Record 19 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 20 of Set 8 | chipinge
# Processing Record 21 of Set 8 | victoria
# Processing Record 22 of Set 8 | maldonado
# Processing Record 23 of Set 8 | buraydah
# Processing Record 24 of Set 8 | moanda
# Processing Record 25 of Set 8 | guarda
# Processing Record 26 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 8 | manokwari
# Processing Record 28 of Set 8 | ribas do rio pardo
# Processing Record 29 of Set 8 | gombong
# Processing Record 30 of Set 8 | alto araguaia
# Processing Record 31 of Set 8 | pine bluff
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | trairi
# Processing Record 34 of Set 8 | ixtapa
# Processing Record 35 of Set 8 | maceio
# Processing Record 36 of Set 8 | dabat
# Processing Record 37 of Set 8 | esso
# Processing Record 38 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 39 of Set 8 | sidi ali
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | khakhea
# Processing Record 42 of Set 8 | mecca
# Processing Record 43 of Set 8 | chabahar
# Processing Record 44 of Set 8 | asfi
# Processing Record 45 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 47 of Set 8 | kodiak
# Processing Record 48 of Set 8 | izhma
# Processing Record 49 of Set 8 | kapoeta
# Processing Record 50 of Set 8 | shostka
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | batagay-alyta
# Processing Record 3 of Set 9 | santa rosa
# Processing Record 4 of Set 9 | muli
# Processing Record 5 of Set 9 | chumikan
# Processing Record 6 of Set 9 | chernyshevskiy
# Processing Record 7 of Set 9 | ornskoldsvik
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 9 | sapouy
# Processing Record 10 of Set 9 | bonfim
# Processing Record 11 of Set 9 | oriximina
# Processing Record 12 of Set 9 | salalah
# Processing Record 13 of Set 9 | arkhangelsk
# Processing Record 14 of Set 9 | port keats
# Processing Record 15 of Set 9 | hirara
# Processing Record 16 of Set 9 | yining
# Processing Record 17 of Set 9 | upata
# Processing Record 18 of Set 9 | iquitos
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | katangli
# Processing Record 21 of Set 9 | porto velho
# Processing Record 22 of Set 9 | mantua
# Processing Record 23 of Set 9 | batsfjord
# Processing Record 24 of Set 9 | abha
# Processing Record 25 of Set 9 | kuandian
# Processing Record 26 of Set 9 | tecoanapa
# Processing Record 27 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 9 | shu
# Processing Record 29 of Set 9 | montrose
# Processing Record 30 of Set 9 | kyabe
# Processing Record 31 of Set 9 | albina
# Processing Record 32 of Set 9 | toamasina
# Processing Record 33 of Set 9 | stekolnyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | meulaboh
# Processing Record 36 of Set 9 | don marcelino
# City not found. Skipping...
# Processing Record 37 of Set 9 | hasaki
# Processing Record 38 of Set 9 | paralimni
# Processing Record 39 of Set 9 | ilulissat
# Processing Record 40 of Set 9 | taurage
# Processing Record 41 of Set 9 | harper
# Processing Record 42 of Set 9 | limbang
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | aldan
# Processing Record 45 of Set 9 | tiksi
# Processing Record 46 of Set 9 | seoul
# Processing Record 47 of Set 9 | franklin
# Processing Record 48 of Set 9 | grimshaw
# Processing Record 49 of Set 9 | tutoia
# Processing Record 50 of Set 9 | la romana
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | lata
# Processing Record 3 of Set 10 | borovoy
# Processing Record 4 of Set 10 | half moon bay
# Processing Record 5 of Set 10 | ust-tsilma
# Processing Record 6 of Set 10 | noumea
# Processing Record 7 of Set 10 | buckeye
# Processing Record 8 of Set 10 | megali khora
# Processing Record 9 of Set 10 | ambovombe
# Processing Record 10 of Set 10 | sambava
# Processing Record 11 of Set 10 | sergeyevka
# Processing Record 12 of Set 10 | torata
# Processing Record 13 of Set 10 | camacupa
# Processing Record 14 of Set 10 | machali
# Processing Record 15 of Set 10 | galesong
# Processing Record 16 of Set 10 | tahta
# Processing Record 17 of Set 10 | marzuq
# Processing Record 18 of Set 10 | yar-sale
# Processing Record 19 of Set 10 | dauphin
# Processing Record 20 of Set 10 | tabou
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | port macquarie
# Processing Record 23 of Set 10 | swansea
# Processing Record 24 of Set 10 | boffa
# Processing Record 25 of Set 10 | esperance
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | wawa
# Processing Record 28 of Set 10 | lompoc
# Processing Record 29 of Set 10 | arys
# Processing Record 30 of Set 10 | balkanabat
# Processing Record 31 of Set 10 | ewa beach
# Processing Record 32 of Set 10 | quebo
# Processing Record 33 of Set 10 | rawson
# Processing Record 34 of Set 10 | davenda
# Processing Record 35 of Set 10 | birin
# Processing Record 36 of Set 10 | ingelheim
# City not found. Skipping...
# Processing Record 37 of Set 10 | charleville-mezieres
# Processing Record 38 of Set 10 | ahipara
# Processing Record 39 of Set 10 | valentin gomez farias
# Processing Record 40 of Set 10 | hofn
# Processing Record 41 of Set 10 | hatfield
# Processing Record 42 of Set 10 | nizhnyaya omka
# Processing Record 43 of Set 10 | kobryn
# Processing Record 44 of Set 10 | paracuru
# Processing Record 45 of Set 10 | kedgwick
# Processing Record 46 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 10 | porto novo
# Processing Record 49 of Set 10 | qui nhon
# Processing Record 50 of Set 10 | montepuez
# Processing Record 1 of Set 11 | stornoway
# Processing Record 2 of Set 11 | grand island
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | korla
# Processing Record 5 of Set 11 | hoi an
# Processing Record 6 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 7 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 11 | mayo
# Processing Record 9 of Set 11 | morehead
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | koslan
# Processing Record 12 of Set 11 | great falls
# Processing Record 13 of Set 11 | guerrero negro
# Processing Record 14 of Set 11 | nexo
# Processing Record 15 of Set 11 | pilani
# Processing Record 16 of Set 11 | rehoboth
# Processing Record 17 of Set 11 | keuruu
# Processing Record 18 of Set 11 | zyryanka
# Processing Record 19 of Set 11 | gat
# Processing Record 20 of Set 11 | santa maria da boa vista
# Processing Record 21 of Set 11 | stokmarknes
# Processing Record 22 of Set 11 | morris
# Processing Record 23 of Set 11 | ngong
# Processing Record 24 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 11 | buin
# Processing Record 27 of Set 11 | krasnoselkup
# Processing Record 28 of Set 11 | arroyo
# Processing Record 29 of Set 11 | labuan
# Processing Record 30 of Set 11 | kavaratti
# Processing Record 31 of Set 11 | christiana
# Processing Record 32 of Set 11 | kokopo
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | pasni
# Processing Record 35 of Set 11 | yekaterinovka
# Processing Record 36 of Set 11 | ilave
# Processing Record 37 of Set 11 | acari
# Processing Record 38 of Set 11 | namatanai
# Processing Record 39 of Set 11 | thaton
# Processing Record 40 of Set 11 | iqaluit
# Processing Record 41 of Set 11 | berlevag
# Processing Record 42 of Set 11 | villa alemana
# Processing Record 43 of Set 11 | narragansett
# Processing Record 44 of Set 11 | nemuro
# Processing Record 45 of Set 11 | inverness
# Processing Record 46 of Set 11 | aleksandrovka
# Processing Record 47 of Set 11 | ancud
# Processing Record 48 of Set 11 | carutapera
# Processing Record 49 of Set 11 | mahanoro
# Processing Record 50 of Set 11 | lyubeshiv
# City not found. Skipping...
# Processing Record 1 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 12 | ginir
# Processing Record 3 of Set 12 | mandalgovi
# Processing Record 4 of Set 12 | amberieu-en-bugey
# Processing Record 5 of Set 12 | mehamn
# Processing Record 6 of Set 12 | ilhabela
# Processing Record 7 of Set 12 | buchanan
# Processing Record 8 of Set 12 | aquiraz
# Processing Record 9 of Set 12 | havelock
# Processing Record 10 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 12 | hamilton
# Processing Record 12 of Set 12 | hvide sande
# Processing Record 13 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 14 of Set 12 | poya
# Processing Record 15 of Set 12 | nsanje
# Processing Record 16 of Set 12 | shalinskoye
# Processing Record 17 of Set 12 | mae sai
# Processing Record 18 of Set 12 | progreso
# Processing Record 19 of Set 12 | barcelos
# Processing Record 20 of Set 12 | salekhard
# Processing Record 21 of Set 12 | cherskiy
# Processing Record 22 of Set 12 | shimoni
# Processing Record 23 of Set 12 | santiago del estero
# Processing Record 24 of Set 12 | torquay
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | nicoya
# Processing Record 27 of Set 12 | elmadag
# Processing Record 28 of Set 12 | portland
# Processing Record 29 of Set 12 | gorontalo
# Processing Record 30 of Set 12 | roros
# Processing Record 31 of Set 12 | anklesvar
# City not found. Skipping...
# Processing Record 32 of Set 12 | ulladulla
# Processing Record 33 of Set 12 | carlagan
# Processing Record 34 of Set 12 | humaita
# Processing Record 35 of Set 12 | lampang
# Processing Record 36 of Set 12 | mitsamiouli
# Processing Record 37 of Set 12 | bajil
# Processing Record 38 of Set 12 | kaka
# Processing Record 39 of Set 12 | rizhao
# Processing Record 40 of Set 12 | uruzgan
# Processing Record 41 of Set 12 | vryburg
# Processing Record 42 of Set 12 | bethanien
# Processing Record 43 of Set 12 | huai mek
# Processing Record 44 of Set 12 | santa clara
# Processing Record 45 of Set 12 | meiganga
# Processing Record 46 of Set 12 | huarmey
# Processing Record 47 of Set 12 | kalanguy
# Processing Record 48 of Set 12 | nizwa
# Processing Record 49 of Set 12 | okha
# Processing Record 50 of Set 12 | imeni poliny osipenko
# Processing Record 1 of Set 13 | tazovskiy
# Processing Record 2 of Set 13 | bulgan
# Processing Record 3 of Set 13 | sakakah
# Processing Record 4 of Set 13 | demyansk
# Processing Record 5 of Set 13 | itagiba
# Processing Record 6 of Set 13 | mitzic
# Processing Record 7 of Set 13 | wolbrom
# Processing Record 8 of Set 13 | oruro
# Processing Record 9 of Set 13 | channel-port aux basques
# Processing Record 10 of Set 13 | fonte boa
# Processing Record 11 of Set 13 | altadena
# Processing Record 12 of Set 13 | rosario
# Processing Record 13 of Set 13 | agirish
# Processing Record 14 of Set 13 | carndonagh
# Processing Record 15 of Set 13 | ongandjera
# Processing Record 16 of Set 13 | ngudu
# Processing Record 17 of Set 13 | nyrob
# Processing Record 18 of Set 13 | abay
# Processing Record 19 of Set 13 | udachnyy
# Processing Record 20 of Set 13 | surt
# Processing Record 21 of Set 13 | pingliang
# Processing Record 22 of Set 13 | siddipet
# Processing Record 23 of Set 13 | hopelchen
# Processing Record 24 of Set 13 | puerto cabezas
# Processing Record 25 of Set 13 | puerto el triunfo
# Processing Record 26 of Set 13 | trinidad
# Processing Record 27 of Set 13 | neubrandenburg
# Processing Record 28 of Set 13 | saint-joseph
# Processing Record 29 of Set 13 | sawtell
# Processing Record 30 of Set 13 | umm bab
# Processing Record 31 of Set 13 | puerto carreno
# Processing Record 32 of Set 13 | bargur
# Processing Record 33 of Set 13 | cacu
# Processing Record 34 of Set 13 | yagodnoye
# Processing Record 35 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 13 | lethem
# Processing Record 37 of Set 13 | yatou
# Processing Record 38 of Set 13 | yenagoa
# Processing Record 39 of Set 13 | lagoa
# Processing Record 40 of Set 13 | smithers
# Processing Record 41 of Set 13 | kendari
# Processing Record 42 of Set 13 | portobelo
# Processing Record 43 of Set 13 | jawhar
# Processing Record 44 of Set 13 | biankouma
# Processing Record 45 of Set 13 | luganville
# Processing Record 46 of Set 13 | te anau
# Processing Record 47 of Set 13 | adrar
# Processing Record 48 of Set 13 | akdepe
# Processing Record 49 of Set 13 | aswan
# Processing Record 50 of Set 13 | casma
# Processing Record 1 of Set 14 | tagusao
# Processing Record 2 of Set 14 | wairoa
# Processing Record 3 of Set 14 | kudahuvadhoo
# Processing Record 4 of Set 14 | atar
# Processing Record 5 of Set 14 | mackenzie
# Processing Record 6 of Set 14 | bireun
# Processing Record 7 of Set 14 | maiduguri
# Processing Record 8 of Set 14 | vidim
# Processing Record 9 of Set 14 | arlit
# Processing Record 10 of Set 14 | geraldton
# Processing Record 11 of Set 14 | homer
# Processing Record 12 of Set 14 | san rafael
# Processing Record 13 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 14 of Set 14 | port blair
# Processing Record 15 of Set 14 | rajakhera
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | tortoli
# Processing Record 18 of Set 14 | barahona
# Processing Record 19 of Set 14 | springbok
# Processing Record 20 of Set 14 | caraballeda
# Processing Record 21 of Set 14 | sterling
# Processing Record 22 of Set 14 | tomatlan
# Processing Record 23 of Set 14 | yantzaza
# Processing Record 24 of Set 14 | gore
# Processing Record 25 of Set 14 | tananger
# Processing Record 26 of Set 14 | argir
# Processing Record 27 of Set 14 | grootfontein
# Processing Record 28 of Set 14 | corvallis
# Processing Record 29 of Set 14 | kortkeros
# Processing Record 30 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 31 of Set 14 | ada
# Processing Record 32 of Set 14 | cabedelo
# Processing Record 33 of Set 14 | kaduna
# Processing Record 34 of Set 14 | belmonte
# Processing Record 35 of Set 14 | zhuozhou
# City not found. Skipping...
# Processing Record 36 of Set 14 | pringsewu
# Processing Record 37 of Set 14 | deputatskiy
# Processing Record 38 of Set 14 | khuzdar
# Processing Record 39 of Set 14 | argentan
# Processing Record 40 of Set 14 | itapua poty
# City not found. Skipping...
# Processing Record 41 of Set 14 | santa cruz
# Processing Record 42 of Set 14 | flin flon
# Processing Record 43 of Set 14 | sayyan
# Processing Record 44 of Set 14 | usinsk
# Processing Record 45 of Set 14 | dicabisagan
# Processing Record 46 of Set 14 | zhangye
# Processing Record 47 of Set 14 | minsk
# Processing Record 48 of Set 14 | sarahan
# Processing Record 49 of Set 14 | rundu
# Processing Record 50 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 15 | syracuse
# Processing Record 2 of Set 15 | pacific grove
# Processing Record 3 of Set 15 | staunton
# Processing Record 4 of Set 15 | eslamshahr
# Processing Record 5 of Set 15 | unity
# Processing Record 6 of Set 15 | matara
# Processing Record 7 of Set 15 | richards bay
# Processing Record 8 of Set 15 | meridian
# Processing Record 9 of Set 15 | namibe
# Processing Record 10 of Set 15 | tucurui
# Processing Record 11 of Set 15 | parnarama
# Processing Record 12 of Set 15 | hualmay
# Processing Record 13 of Set 15 | talara
# Processing Record 14 of Set 15 | necochea
# Processing Record 15 of Set 15 | peniche
# Processing Record 16 of Set 15 | colares
# Processing Record 17 of Set 15 | sao lourenco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 660

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Saint-Philippe -21.3585   55.7679     71.19        83          58
# 1              Bluff -46.6000  168.3333     58.80        78         100
# 2       Puerto Ayora  -0.7393  -90.3518     76.96        82          73
# 3           Svetlaya  46.5389  138.3297     42.91        74         100
# 4           Katsuura  35.1333  140.3000     63.39        81          26
# 5  San Juan Bautista -14.0108  -75.7358     84.87        34          70
# 6          Hithadhoo  -0.6000   73.0833     81.03        78         100
# 7             Atuona  -9.8000 -139.0333     77.32        81          11
# 8          Iskateley  67.6803   53.1512     14.34        95          87
# 9          Havoysund  70.9963   24.6622     34.03        83         100
#
#    Wind Speed Country Current Description
# 0        8.52      RE       broken clouds
# 1        4.90      NZ     overcast clouds
# 2       10.00      EC       broken clouds
# 3       10.00      RU     overcast clouds
# 4        6.15      JP    scattered clouds
# 5       14.79      PE       broken clouds
# 6       14.63      MV     overcast clouds
# 7       14.67      PF          few clouds
# 8        8.34      RU     overcast clouds
# 9        3.65      NO     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
modified_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[modified_columns]

# Display sample data
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Saint-Philippe      RE -21.3585   55.7679     71.19        83
# 1              Bluff      NZ -46.6000  168.3333     58.80        78
# 2       Puerto Ayora      EC  -0.7393  -90.3518     76.96        82
# 3           Svetlaya      RU  46.5389  138.3297     42.91        74
# 4           Katsuura      JP  35.1333  140.3000     63.39        81
# 5  San Juan Bautista      PE -14.0108  -75.7358     84.87        34
# 6          Hithadhoo      MV  -0.6000   73.0833     81.03        78
# 7             Atuona      PF  -9.8000 -139.0333     77.32        81
# 8          Iskateley      RU  67.6803   53.1512     14.34        95
# 9          Havoysund      NO  70.9963   24.6622     34.03        83
#
#    Cloudiness  Wind Speed Current Description
# 0          58        8.52       broken clouds
# 1         100        4.90     overcast clouds
# 2          73       10.00       broken clouds
# 3         100       10.00     overcast clouds
# 4          26        6.15    scattered clouds
# 5          70       14.79       broken clouds
# 6         100       14.63     overcast clouds
# 7          11       14.67          few clouds
# 8          87        8.34     overcast clouds
# 9         100        3.65     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file ="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
